# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
# !unzip '/content/drive/My Drive/Tf5/object_detection.zip' -d '/content/drive/My Drive/Tf5/'

# %%
# !pip install tf-models-official
# !pip install tf_slim

# %%
# %cd '/content/drive/My Drive/Tf5/object_detection'
# Out:
# /content/drive/My Drive/Tf5/object_detection

# %%
# !python model_main_tf2.py --pipeline_config_path=training/ssd_efficientdet_d0_512x512_coco17_tpu-8.config --model_dir=training --alsologtostderr

# %%
# !pip install lvis

# %%
# !pip install tensorflow_io

# %%
# !python exporter_main_v2.py --trained_checkpoint_dir=training --pipeline_config_path=training/ssd_efficientdet_d0_512x512_coco17_tpu-8.config --output_directory inference_graph
